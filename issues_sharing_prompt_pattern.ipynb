# %%
import glob
import json
from datetime import datetime
import pandas as pd

# %%
# Path pattern to locate all JSON files across snapshots
file_pattern = "C:/Users/Sandeep Kumar/Desktop/pree/DevGPT/snapshot_*/*_issue_sharings.json"

# Initialize an empty list to store all JSON data
all_data = []

# Loop through all matching file paths and load each file
for path in glob.glob(file_pattern):
    print(path)
    with open(path, "r") as file:
        data = json.load(file)
        all_data.append(data)

# all_data now contains data from all JSON files
print(f"Total files read: {len(all_data)}")
# Out:
# C:/Users/Sandeep Kumar/Desktop/pree/DevGPT\snapshot_20230727\20230727_195941_issue_sharings.json
# C:/Users/Sandeep Kumar/Desktop/pree/DevGPT\snapshot_20230803\20230803_094705_issue_sharings.json
# C:/Users/Sandeep Kumar/Desktop/pree/DevGPT\snapshot_20230810\20230810_123938_issue_sharings.json
# C:/Users/Sandeep Kumar/Desktop/pree/DevGPT\snapshot_20230817\20230817_130502_issue_sharings.json
# C:/Users/Sandeep Kumar/Desktop/pree/DevGPT\snapshot_20230824\20230824_101836_issue_sharings.json
# C:/Users/Sandeep Kumar/Desktop/pree/DevGPT\snapshot_20230831\20230831_061759_issue_sharings.json
# C:/Users/Sandeep Kumar/Desktop/pree/DevGPT\snapshot_20230907\20230907_092956_issue_sharings.json
# C:/Users/Sandeep Kumar/Desktop/pree/DevGPT\snapshot_20230914\20230914_080417_issue_sharings.json
# C:/Users/Sandeep Kumar/Desktop/pree/DevGPT\snapshot_20231012\20231012_235128_issue_sharings.json
# Total files read: 9

# %%
# Initialize a list for rows that will form the DataFrame
rows = []

# Define the pattern analysis function
def analyze_prompt_structure(data):
    detected_patterns = []
    
    persona_keywords = ["you are", "act as", "pretend to be", "pretend you are"]
    recipe_keywords = ["step-by-step", "recipe", "guide"]
    template_keywords = ["template", "formatting"]
    automator_keywords = ["script", "code", "executable"]
    simple_instruction_keywords = ["explain", "describe", "list", "tell me", "give me"]
    context_instruction_keywords = ["based on", "with this information"]
    question_keywords = ["what", "where", "when", "who", "why"]

    def contains_keywords(text, keywords):
        return any(keyword in text.lower() for keyword in keywords)

    for source in data.get("Sources", []):
        body = source.get("Body", "")
        created_at = source.get("CreatedAt")
        closed_at = source.get("ClosedAt")
        state = "Closed" if closed_at is not None else "Open"

        time_lapsed = None
        if created_at and closed_at:
            created_at_dt = datetime.strptime(created_at, "%Y-%m-%dT%H:%M:%SZ")
            closed_at_dt = datetime.strptime(closed_at, "%Y-%m-%dT%H:%M:%SZ")
            time_lapsed = closed_at_dt - created_at_dt

        body_patterns = []

        # Check for patterns in the body text
        if contains_keywords(body, persona_keywords):
            body_patterns.append("Persona Pattern")
        if contains_keywords(body, recipe_keywords):
            body_patterns.append("Recipe Pattern")
        if contains_keywords(body, template_keywords):
            body_patterns.append("Template Pattern")
        if contains_keywords(body, automator_keywords):
            body_patterns.append("Output Automator Pattern")
        if contains_keywords(body, simple_instruction_keywords):
            body_patterns.append("Simple Instruction Pattern")
        if contains_keywords(body, context_instruction_keywords):
            body_patterns.append("Context and Instruction Pattern")
        if contains_keywords(body, question_keywords):
            body_patterns.append("Question Pattern")

        conversations = source.get("ChatgptSharing", [])
        for item in conversations:
            number_of_prompts = item.get("NumberOfPrompts", "N/A")
            conversation_url = item.get("URL", "N/A")

            for pattern in body_patterns:
                detected_patterns.append((
                    source['Number'],
                    pattern,
                    state,
                    time_lapsed,
                    number_of_prompts,
                    conversation_url
                ))

    return detected_patterns

# %%
# Loop through each dictionary in all_data
for data_dict in all_data:
    # Check if 'Sources' key exists in each dictionary
    if 'Sources' in data_dict:
        for item in data_dict['Sources']:
            if 'ChatgptSharing' in item:
                for sharing in item['ChatgptSharing']:
                    if 'Conversations' in sharing:
                        for conversation in sharing['Conversations']:
                            # Adding the fields to row
                            row = {
                                "Type": item.get('Type'),
                                "URL": item.get('URL'),
                                "Author": item.get('Author'),
                                "RepoName": item.get('RepoName'),
                                "RepoLanguage": item.get('RepoLanguage'),
                                "Number": item.get('Number'),
                                "Title": item.get('Title'),
                                "Body": item.get('Body'),
                                "UpdatedAt": item.get('UpdatedAt'),
                                "State": item.get('State'),
                                "CSharing_URL": sharing.get('URL'),
                                "CSharing_Status": sharing.get('Status'),
                                "CSharing_DateOfConversation": sharing.get('DateOfConversation'),
                                "CSharing_Title": sharing.get('Title'),
                                "CSharing_NumberOfPrompts": sharing.get('NumberOfPrompts'),
                                "CSharing_TokensOfPrompts": sharing.get('TokensOfPrompts'),
                                "CSharing_TokensOfAnswers": sharing.get('TokensOfAnswers'),
                                "Conversation_Prompt": conversation.get('Prompt'),
                                "Conversation_Answer": conversation.get('Answer')
                            }
                            rows.append(row)

# Create DataFrame from rows
df = pd.DataFrame(rows)

# %%
# Detect patterns for each source and add to the DataFrame
detected_patterns = analyze_prompt_structure(data_dict)  # Use the last data_dict for patterns

# %%
# Prepare a dictionary to store detected patterns for easy lookup
pattern_dict = {}
for number, pattern, state, time_lapsed, number_of_prompts, conversation_url in detected_patterns:
    if number not in pattern_dict:
        pattern_dict[number] = []
    pattern_dict[number].append(pattern)

# Add a new column for detected patterns
df['Detected Patterns'] = df['Number'].map(lambda x: ', '.join(pattern_dict.get(x, [])))

# %%
df.info
# Out:
# <bound method DataFrame.info of         Type                                                URL        Author  \
# 0      issue  https://github.com/gakusyutai/gakusyutai.githu...        yuyu31
# 1      issue  https://github.com/gakusyutai/gakusyutai.githu...        yuyu31
# 2      issue  https://github.com/gakusyutai/gakusyutai.githu...        yuyu31
# 3      issue  https://github.com/gakusyutai/gakusyutai.githu...        yuyu31
# 4      issue  https://github.com/gakusyutai/gakusyutai.githu...        yuyu31
# ...      ...                                                ...           ...
# 14559  issue  https://github.com/open-spaced-repetition/fsrs...  L-M-Sherlock
# 14560  issue  https://github.com/open-spaced-repetition/fsrs...  L-M-Sherlock
# 14561  issue  https://github.com/microsoft/TypeScript/issues...   nitzantomer
# 14562  issue  https://github.com/microsoft/TypeScript/issues...   nitzantomer
# 14563  issue  https://github.com/microsoft/TypeScript/issues...   nitzantomer
#
#                                RepoName      RepoLanguage  Number  \
# 0       gakusyutai/gakusyutai.github.io              HTML      31
# 1       gakusyutai/gakusyutai.github.io              HTML      31
# 2       gakusyutai/gakusyutai.github.io              HTML      31
# 3       gakusyutai/gakusyutai.github.io              HTML      31
# 4       gakusyutai/gakusyutai.github.io              HTML      31
# ...                                 ...               ...     ...
# 14559  open-spaced-repetition/fsrs4anki  Jupyter Notebook     351
# 14560  open-spaced-repetition/fsrs4anki  Jupyter Notebook     351
# 14561              microsoft/TypeScript        TypeScript   13219
# 14562              microsoft/TypeScript        TypeScript   13219
# 14563              microsoft/TypeScript        TypeScript   13219
#
#                                                    Title  \
# 0                                          ハンバーガーメニューの実装
# 1                                          ハンバーガーメニューの実装
# 2                                          ハンバーガーメニューの実装
# 3                                          ハンバーガーメニューの実装
# 4                                          ハンバーガーメニューの実装
# ...                                                  ...
# 14559                     [Doc] Introduction for FSRS v4
# 14560                     [Doc] Introduction for FSRS v4
# 14561  Suggestion: `throws` clause and typed catch cl...
# 14562  Suggestion: `throws` clause and typed catch cl...
# 14563  Suggestion: `throws` clause and typed catch cl...
#
#                                                     Body  \
# 0      - https://chat.openai.com/share/8b0f517f-1aaf-...
# 1      - https://chat.openai.com/share/8b0f517f-1aaf-...
# 2      - https://chat.openai.com/share/8b0f517f-1aaf-...
# 3      - https://chat.openai.com/share/8b0f517f-1aaf-...
# 4      - https://chat.openai.com/share/8b0f517f-1aaf-...
# ...                                                  ...
# 14559  1) Re-writing the wiki. I suggest opening a ne...
# 14560  1) Re-writing the wiki. I suggest opening a ne...
# 14561  The typescript type system is helpful in most ...
# 14562  The typescript type system is helpful in most ...
# 14563  The typescript type system is helpful in most ...
#
#                   UpdatedAt   State  \
# 0      2023-07-23T15:38:42Z    OPEN
# 1      2023-07-23T15:38:42Z    OPEN
# 2      2023-07-23T15:38:42Z    OPEN
# 3      2023-07-23T15:38:42Z    OPEN
# 4      2023-07-23T15:38:42Z    OPEN
# ...                     ...     ...
# 14559  2023-09-20T15:56:42Z  CLOSED
# 14560  2023-09-20T15:56:42Z  CLOSED
# 14561  2023-08-28T16:14:20Z  CLOSED
# 14562  2023-08-28T16:14:20Z  CLOSED
# 14563  2023-08-28T16:14:20Z  CLOSED
#
#                                             CSharing_URL  CSharing_Status  \
# 0      https://chat.openai.com/share/7958273c-0081-48...              200
# 1      https://chat.openai.com/share/7958273c-0081-48...              200
# 2      https://chat.openai.com/share/7958273c-0081-48...              200
# 3      https://chat.openai.com/share/7958273c-0081-48...              200
# 4      https://chat.openai.com/share/7958273c-0081-48...              200
# ...                                                  ...              ...
# 14559  https://chat.openai.com/share/e6821881-b4ab-47...              200
# 14560  https://chat.openai.com/share/e6821881-b4ab-47...              200
# 14561  https://chat.openai.com/share/8354ae88-a968-41...              200
# 14562  https://chat.openai.com/share/8354ae88-a968-41...              200
# 14563  https://chat.openai.com/share/8354ae88-a968-41...              200
#
#       CSharing_DateOfConversation                     CSharing_Title  \
# 0                    July 6, 2023                    ハンバーガーメニュー表示の修正
# 1                    July 6, 2023                    ハンバーガーメニュー表示の修正
# 2                    July 6, 2023                    ハンバーガーメニュー表示の修正
# 3                    July 6, 2023                    ハンバーガーメニュー表示の修正
# 4                    July 6, 2023                    ハンバーガーメニュー表示の修正
# ...                           ...                                ...
# 14559  Jarrett Ye•August 20, 2023            Rewriting FSRS Tutorial
# 14560  Jarrett Ye•August 20, 2023            Rewriting FSRS Tutorial
# 14561             August 25, 2023  TypeScript: No Checked Exceptions
# 14562             August 25, 2023  TypeScript: No Checked Exceptions
# 14563             August 25, 2023  TypeScript: No Checked Exceptions
#
#        CSharing_NumberOfPrompts  CSharing_TokensOfPrompts  \
# 0                            11                      2637
# 1                            11                      2637
# 2                            11                      2637
# 3                            11                      2637
# 4                            11                      2637
# ...                         ...                       ...
# 14559                         4                       173
# 14560                         4                       173
# 14561                         4                       279
# 14562                         4                       279
# 14563                         4                       279
#
#        CSharing_TokensOfAnswers  \
# 0                          4712
# 1                          4712
# 2                          4712
# 3                          4712
# 4                          4712
# ...                         ...
# 14559                      1110
# 14560                      1110
# 14561                      1341
# 14562                      1341
# 14563                      1341
#
#                                      Conversation_Prompt  \
# 0      あなたはwebデザイナーです。ハンバーガーメニューを実装したところ、初めからメニューの内容が...
# 1                                   「ハンバーガーメニュー」とはなんですか。
# 2      そうですね。ありがとうございます。\n\n今回は初めから「ハンバーガーメニュー」が表示されて...
# 3                                          変更点を解説してください。
# 4      変更を加えましたが、メニューが最初から表示されていて、ハンバーガーアイコンをクリックしても切...
# ...                                                  ...
# 14559                                           continue
# 14560                                            proceed
# 14561  I wish that in typescript I could mark a funct...
# 14562  Are there no other options that use static ana...
# 14563  Write me an eslint rule that would warn on the...
#
#                                      Conversation_Answer  \
# 0      ハンバーガーメニューが初めから表示されており、表示非表示を切り替えることができない理由は、c...
# 1      ハンバーガーメニュー（Hamburger menu）は、ウェブデザインやユーザーインターフェ...
# 2      申し訳ありません、誤解が生じました。ハンバーガーメニューの問題点について理解しました。メニュ...
# 3      修正点を以下で解説します。.containerクラスにdisplay: none;のスタイル...
# 4      申し訳ありません、再度問題を確認いたしました。修正が不足していたため、以下の修正を加えてくだ...
# ...                                                  ...
# 14559  ChatGPTUsed WebPilotThe version of the FSRS tu...
# 14560  ChatGPTUsed WebPilotThe version of the FSRS tu...
# 14561  ChatGPTAs of my knowledge cutoff in September ...
# 14562  ChatGPTAs of my knowledge cut-off in September...
# 14563  ChatGPTSure! To create this custom ESLint rule...
#
#                                        Detected Patterns
# 0      Question Pattern, Output Automator Pattern, Qu...
# 1      Question Pattern, Output Automator Pattern, Qu...
# 2      Question Pattern, Output Automator Pattern, Qu...
# 3      Question Pattern, Output Automator Pattern, Qu...
# 4      Question Pattern, Output Automator Pattern, Qu...
# ...                                                  ...
# 14559
# 14560
# 14561         Output Automator Pattern, Question Pattern
# 14562         Output Automator Pattern, Question Pattern
# 14563         Output Automator Pattern, Question Pattern
#
# [14564 rows x 20 columns]>

# %%
# Save the DataFrame to a CSV file
df.to_csv('issues_sharing_visualize_output_with_patterns.csv', index=False)
